# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\nbhaa\onedrive\desktop\sample_project_1\env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import seaborn as sns

# %%
df=pd.read_csv('dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.scatterplot(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 sns.scatterplot(x)
#
# NameError: name 'x' is not defined

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(x='salary',y='sales',data=df,
                hue='level of education',
                #palette='Dark2',
                #size='salary',
                s=200,
                #alpha=0.2
                 style='level of education');
plt.savefig("my_plt_2.jpg")

# %%
df=pd.read_csv("dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(5,8),dpi=200)
sns.rugplot(x="salary",data=df,height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
# sns.set(style='darkgrid')
sns.set(style='white')
sns.displot(data=df,x='salary',bins=20,
         #color='red',edgecolor='blue',
          # linewidth=4,ls='--',
            kde=True,rug=True
           )

# %%
sns.histplot(data=df,x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
np.random.seed(42) 
sample_ages=np.random.randint(0,100,200)

# %%
sample_ages.size
# Out:
# 200

# %%
sample_ages=pd.DataFrame(sample_ages,columns=['age'])

# %%
sample_ages
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages,x='age')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.displot(data=sample_ages,x='age',rug=True,bins=30,kde=True)

# %%
sns.kdeplot(data=sample_ages,x='age',clip=[0,100],bw_adjust=.6,shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df=pd.read_csv("dm_office_sales.csv")

# %%
df.head(20)
# Out:
#              division  level of education  training level  work experience  \
# 0            printers        some college               2                6
# 1            printers  associate's degree               2               10
# 2         peripherals         high school               0                9
# 3     office supplies  associate's degree               2                5
# 4     office supplies         high school               1                5
# 5   computer hardware        some college               0               10
# 6         peripherals  associate's degree               0                5
# 7     office supplies        some college               0                6
# 8            printers  associate's degree               3                2
# 9   computer hardware  associate's degree               1                5
# 10           printers  associate's degree               2                3
# 11        peripherals  associate's degree               2                6
# 12    office supplies        some college               0                6
# 13    office supplies        some college               3                4
# 14           printers        some college               3                6
# 15           printers  associate's degree               2                7
# 16           printers        some college               1                7
# 17  computer software        some college               1                0
# 18    office supplies        some college               2                9
# 19    office supplies        some college               0                6
#
#     salary   sales
# 0    91684  372302
# 1   119679  495660
# 2    82045  320453
# 3    92949  377148
# 4    71280  312802
# 5   102401  366451
# 6    77548  230899
# 7    81966  265915
# 8    72844  308443
# 9    96731  326667
# 10   73508  251044
# 11   97841  382063
# 12   82719  245873
# 13   98070  410695
# 14   94604  448108
# 15  105864  427161
# 16   79103  306233
# 17   70834  156285
# 18  109279  463564
# 19   77126  265805

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=df,x='division');
sns.countplot(data=df,x='level of education',hue='division',palette='Set2');
# plt.ylim(90,260)

# %%
df['level of education'].value_counts()
# Out:
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: level of education, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(data=df,x='level of education',y='salary',estimator=np.mean,ci='sd',
            hue='division')
plt.legend(bbox_to_anchor=(1.05,1))

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.boxplot(data=df,x='reading score',y='parental level of education',
           hue='test preparation course',palette='Set2')
plt.legend(bbox_to_anchor=(1.05,0.5))

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.violinplot(data=df,x='reading score',y='parental level of education',
           hue='test preparation course',palette='Set2',split=True)
plt.legend(bbox_to_anchor=(1.25,0.5))

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.violinplot(data=df,x='reading score',y='parental level of education',
           hue='test preparation course',palette='Set2',split=True,
#                ,inner=None
#                inner='quartile'
                inner='stick')
plt.legend(bbox_to_anchor=(1.25,0.5))

# %%
plt.figure(figsize=(10,8),dpi=200)
sns.violinplot(data=df,x='reading score',y='parental level of education',
#            hue='test preparation course',palette='Set2',split=True,
#                ,inner=None
               inner='quartile')
# plt.legend(bbox_to_anchor=(1.25,0.5))
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='parental level of education'>

# %%
sns.swarmplot(data=df,x='math score',y='gender',size=2,
             hue='test preparation course',dodge=True)
plt.legend(bbox_to_anchor=(1.35,0.5))

# %%
sns.boxenplot(x='math score',y='test preparation course',
             data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='math score', ylabel='test preparation course'>

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(data=df,x='math score',y='reading score',
             alpha=0.2)

# %%
sns.jointplot(data=df,x='math score',y='reading score',kind='hex')

# %%
sns.jointplot(data=df,x='math score',y='reading score',kind='hist')

# %%
sns.jointplot(data=df,x='math score',y='reading score',kind='kde',shade=True)

# %%
sns.jointplot(data=df,x='math score',y='reading score',hue='gender')

# %%
sns.pairplot(data=df,hue='gender')

# %%
sns.pairplot(data=df,hue='gender',diag_kind='hist')

# %%
sns.pairplot(data=df,hue='gender',corner=True)

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(data=df,x='gender',y='math score',kind='box',
            col='lunch',row='test preparation course');

# %%
sns.catplot(data=df,x='gender',y='math score',kind='violin',
            col='lunch',row='race/ethnicity');

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
g=sns.PairGrid(df)

g=g.map_upper(sns.scatterplot)

g=g.map_diag(sns.kdeplot)

g.map_lower(sns.kdeplot)

# %%
g=sns.PairGrid(df,hue='gender')

g=g.map_upper(sns.scatterplot)

g=g.map_diag(sns.kdeplot)

g.map_lower(sns.kdeplot)

g.add_legend()

# %%
df=pd.read_csv('country_table.csv')

# %%
df
# Out:
#                          Countries  Birth rate  Mortality rate  \
# 0                           AFRICA      32.577           7.837
# 1                             ASIA      15.796           7.030
# 2                           EUROPE      10.118          11.163
# 3  LATIN AMERICA AND THE CARIBBEAN      15.886           6.444
# 4                 NORTHERN AMERICA      11.780           8.833
# 5                          OCEANIA      16.235           6.788
# 6                            WORLD      17.963           7.601
#
#    Life expectancy  Infant mortality rate  Growth rate
# 0           63.472                 44.215        24.40
# 1           73.787                 23.185         8.44
# 2           78.740                  3.750         0.38
# 3           75.649                 14.570         8.89
# 4           79.269                  5.563         6.11
# 5           78.880                 16.939        12.79
# 6           72.766                 27.492        10.36

# %%
a=df

# %%
sns.heatmap(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 sns.heatmap(a)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:159, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     156 self.ylabel = ylabel if ylabel is not None else ""
#     158 # Determine good default values for the colormapping
# --> 159 self._determine_cmap_params(plot_data, vmin, vmax,
#     160                             cmap, center, robust)
#     162 # Sort out the annotations
#     163 if annot is None or annot is False:
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:193, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     190 """Use some heuristics to set good defaults for colorbar and range."""
#     192 # plot_data is a np.ma.array instance
# --> 193 calc_data = plot_data.astype(float).filled(np.nan)
#     194 if vmin is None:
#     195     if robust:
#
# ValueError: could not convert string to float: 'AFRICA'

# %%
df=df.set_index('Countries');

# %%
df
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# LATIN AMERICA AND THE CARIBBEAN                 14.570         8.89
# NORTHERN AMERICA                                 5.563         6.11
# OCEANIA                                         16.939        12.79
# WORLD                                           27.492        10.36

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
sns.heatmap(df.drop('Life expectancy',axis=1))
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,
            cmap='viridis')
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.heatmap(df.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,
            cmap='viridis',center=40)
# Out:
# <AxesSubplot:ylabel='Countries'>

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,
            cmap='viridis')

# %%
plt.figure(dpi=200)
sns.clustermap(df.drop('Life expectancy',axis=1),linewidth=0.5,annot=True,
            cmap='viridis',col_cluster=False)
